# %%
import numpy as np
import pandas as pd
import seaborn as srn
from matplotlib import pyplot as plt

# %%
table = pd.read_csv('metrics.csv')
table
# Out:
#      Unnamed: 0 algorithm  dim difficulty  index_map  distance      ram  \
# 0             0       bfs   10          F          1      18.0  26779.0
# 1             1       bfs   10          F          2      18.0  26779.0
# 2             2       bfs   10          F          3      18.0  26779.0
# 3             3       bfs   10          F          4      18.0  26779.0
# 4             4       bfs   10          F          5      18.0  26779.0
# ..          ...       ...  ...        ...        ...       ...      ...
# 265         265  prog_din   50          D          6      98.0  26779.0
# 266         266  prog_din   50          D          7      98.0  26779.0
# 267         267  prog_din   50          D          8      98.0  26779.0
# 268         268  prog_din   50          D          9      98.0  26779.0
# 269         269  prog_din   50          D         10      98.0  26779.0
#
#          time
# 0    0.001742
# 1    0.001636
# 2    0.001749
# 3    0.001617
# 4    0.001612
# ...

# %%
bfs = table.loc[table['algorithm'] == 'bfs']
bfsF = bfs.loc[table['difficulty'] == 'F']
bfsF10 = bfsF.loc[table['dim'] == 10]
bfsF20 = bfsF.loc[table['dim'] == 20]
bfsF50 = bfsF.loc[table['dim'] == 50]

bfs = table.loc[table['algorithm'] == 'bfs']
bfsM = bfs.loc[table['difficulty'] == 'M']
bfsM10 = bfsM.loc[table['dim'] == 10]
bfsM20 = bfsM.loc[table['dim'] == 20]
bfsM50 = bfsM.loc[table['dim'] == 50]

bfs = table.loc[table['algorithm'] == 'bfs']
bfsD = bfs.loc[table['difficulty'] == 'D']
bfsD10 = bfsD.loc[table['dim'] == 10]
bfsD20 = bfsD.loc[table['dim'] == 20]
bfsD50 = bfsD.loc[table['dim'] == 50]

kohonen = table.loc[table['algorithm'] == 'kohonen']
kohonenF = kohonen.loc[table['difficulty'] == 'F']
kohonenF10 = kohonenF.loc[table['dim'] == 10]
kohonenF20 = kohonenF.loc[table['dim'] == 20]
kohonenF50 = kohonenF.loc[table['dim'] == 50]

kohonen = table.loc[table['algorithm'] == 'kohonen']
kohonenM = kohonen.loc[table['difficulty'] == 'M']
kohonenM10 = kohonenM.loc[table['dim'] == 10]
kohonenM20 = kohonenM.loc[table['dim'] == 20]
kohonenM50 = kohonenM.loc[table['dim'] == 50]

kohonen = table.loc[table['algorithm'] == 'kohonen']
kohonenD = kohonen.loc[table['difficulty'] == 'D']
kohonenD10 = kohonenD.loc[table['dim'] == 10]
kohonenD20 = kohonenD.loc[table['dim'] == 20]
kohonenD50 = kohonenD.loc[table['dim'] == 50]

prog_din = table.loc[table['algorithm'] == 'prog_din']
prog_dinF = prog_din.loc[table['difficulty'] == 'F']
prog_dinF10 = prog_dinF.loc[table['dim'] == 10]
prog_dinF20 = prog_dinF.loc[table['dim'] == 20]
prog_dinF50 = prog_dinF.loc[table['dim'] == 50]

prog_din = table.loc[table['algorithm'] == 'prog_din']
prog_dinM = prog_din.loc[table['difficulty'] == 'M']
prog_dinM10 = prog_dinM.loc[table['dim'] == 10]
prog_dinM20 = prog_dinM.loc[table['dim'] == 20]
prog_dinM50 = prog_dinM.loc[table['dim'] == 50]

prog_din = table.loc[table['algorithm'] == 'prog_din']
prog_dinD = prog_din.loc[table['difficulty'] == 'D']
prog_dinD10 = prog_dinD.loc[table['dim'] == 10]
prog_dinD20 = prog_dinD.loc[table['dim'] == 20]
prog_dinD50 = prog_dinD.loc[table['dim'] == 50]

# %%
bfsF10.describe()
# Out:
#        Unnamed: 0   dim  index_map  distance      ram       time
# count    10.00000  10.0   10.00000      10.0     10.0  10.000000
# mean      4.50000  10.0    5.50000      18.0  26779.0   0.001658
# std       3.02765   0.0    3.02765       0.0      0.0   0.000048
# min       0.00000  10.0    1.00000      18.0  26779.0   0.001612
# 25%       2.25000  10.0    3.25000      18.0  26779.0   0.001632
# 50%       4.50000  10.0    5.50000      18.0  26779.0   0.001642
# 75%       6.75000  10.0    7.75000      18.0  26779.0   0.001658
# max       9.00000  10.0   10.00000      18.0  26779.0   0.001749

# %%
bfsF20.describe()
# Out:
#        Unnamed: 0   dim  index_map  distance           ram       time
# count    10.00000  10.0   10.00000      10.0     10.000000  10.000000
# mean     94.50000  20.0    5.50000      38.0  78008.000000   0.007490
# std       3.02765   0.0    3.02765       0.0   1754.708206   0.000668
# min      90.00000  20.0    1.00000      38.0  74324.000000   0.006907
# 25%      92.25000  20.0    3.25000      38.0  77316.000000   0.007204
# 50%      94.50000  20.0    5.50000      38.0  78384.000000   0.007287
# 75%      96.75000  20.0    7.75000      38.0  79084.000000   0.007434
# max      99.00000  20.0   10.00000      38.0  80156.000000   0.009284

# %%
bfsF50.describe()
# Out:
#        Unnamed: 0   dim  index_map  distance            ram       time
# count    10.00000  10.0   10.00000      10.0      10.000000  10.000000
# mean    184.50000  50.0    5.50000      98.0  346654.400000   0.045964
# std       3.02765   0.0    3.02765       0.0    2607.495657   0.002526
# min     180.00000  50.0    1.00000      98.0  340724.000000   0.042537
# 25%     182.25000  50.0    3.25000      98.0  346004.000000   0.044256
# 50%     184.50000  50.0    5.50000      98.0  346868.000000   0.045665
# 75%     186.75000  50.0    7.75000      98.0  348274.000000   0.047132
# max     189.00000  50.0   10.00000      98.0  350004.000000   0.051142

# %%
bfsD10.describe()
# Out:
#        Unnamed: 0   dim  index_map  distance      ram       time
# count    10.00000  10.0   10.00000      10.0     10.0  10.000000
# mean     64.50000  10.0    5.50000      18.0  26779.0   0.001301
# std       3.02765   0.0    3.02765       0.0      0.0   0.000165
# min      60.00000  10.0    1.00000      18.0  26779.0   0.001106
# 25%      62.25000  10.0    3.25000      18.0  26779.0   0.001190
# 50%      64.50000  10.0    5.50000      18.0  26779.0   0.001253
# 75%      66.75000  10.0    7.75000      18.0  26779.0   0.001363
# max      69.00000  10.0   10.00000      18.0  26779.0   0.001631

# %%
bfsD20.describe()
# Out:
#        Unnamed: 0   dim  index_map  distance           ram       time
# count    10.00000  10.0   10.00000      10.0     10.000000  10.000000
# mean    154.50000  20.0    5.50000      38.0  63672.800000   0.006114
# std       3.02765   0.0    3.02765       0.0  18561.309226   0.001448
# min     150.00000  20.0    1.00000      38.0  34772.000000   0.003633
# 25%     152.25000  20.0    3.25000      38.0  48586.000000   0.005473
# 50%     154.50000  20.0    5.50000      38.0  72256.000000   0.006270
# 75%     156.75000  20.0    7.75000      38.0  75108.000000   0.006521
# max     159.00000  20.0   10.00000      38.0  79724.000000   0.009147

# %%
bfsD50.describe()
# Out:
#        Unnamed: 0   dim  index_map  distance            ram       time
# count    10.00000  10.0   10.00000      10.0      10.000000  10.000000
# mean    244.50000  50.0    5.50000      98.0  322402.400000   0.039811
# std       3.02765   0.0    3.02765       0.0   30993.327293   0.006148
# min     240.00000  50.0    1.00000      98.0  263476.000000   0.027079
# 25%     242.25000  50.0    3.25000      98.0  308588.000000   0.038108
# 50%     244.50000  50.0    5.50000      98.0  336888.000000   0.042433
# 75%     246.75000  50.0    7.75000      98.0  344112.000000   0.043833
# max     249.00000  50.0   10.00000      98.0  349604.000000   0.045142

# %%
kohonenF10.describe()
# Out:
#        Unnamed: 0   dim  index_map   distance      ram        time
# count    10.00000  10.0   10.00000  10.000000     10.0   10.000000
# mean     14.50000  10.0    5.50000  20.028756  28811.0  127.048879
# std       3.02765   0.0    3.02765   1.488905      0.0    1.503386
# min      10.00000  10.0    1.00000  17.286693  28811.0  124.959340
# 25%      12.25000  10.0    3.25000  20.019996  28811.0  125.632763
# 50%      14.50000  10.0    5.50000  20.257983  28811.0  127.164287
# 75%      16.75000  10.0    7.75000  20.789858  28811.0  128.296389
# max      19.00000  10.0   10.00000  21.773999  28811.0  129.020108

# %%
kohonenF20.describe()
# Out:
#        Unnamed: 0   dim  index_map   distance      ram        time
# count    10.00000  10.0   10.00000  10.000000     10.0   10.000000
# mean    104.50000  20.0    5.50000  53.711722  29131.0  269.850668
# std       3.02765   0.0    3.02765   2.692011      0.0    6.320639
# min     100.00000  20.0    1.00000  50.014185  29131.0  258.813286
# 25%     102.25000  20.0    3.25000  51.920207  29131.0  264.794430
# 50%     104.50000  20.0    5.50000  53.480517  29131.0  272.269536
# 75%     106.75000  20.0    7.75000  54.060184  29131.0  274.831240
# max     109.00000  20.0   10.00000  59.029351  29131.0  275.420349

# %%
kohonenF50.describe()
# Out:
#        Unnamed: 0   dim  index_map    distance      ram        time
# count    10.00000  10.0   10.00000   10.000000     10.0   10.000000
# mean    194.50000  50.0    5.50000  176.109686  30091.0  673.846027
# std       3.02765   0.0    3.02765    9.404789      0.0    8.880757
# min     190.00000  50.0    1.00000  160.682803  30091.0  658.974360
# 25%     192.25000  50.0    3.25000  168.844981  30091.0  667.998603
# 50%     194.50000  50.0    5.50000  176.083405  30091.0  674.157327
# 75%     196.75000  50.0    7.75000  181.814292  30091.0  680.355113
# max     199.00000  50.0   10.00000  191.980739  30091.0  686.534188

# %%
kohonenD10.describe()
# Out:
#        Unnamed: 0   dim  index_map       distance           ram        time
# count    10.00000  10.0   10.00000   1.000000e+01     10.000000   10.000000
# mean     74.50000  10.0    5.50000            inf  29496.900000  138.052273
# std       3.02765   0.0    3.02765            NaN   2169.006247    2.623259
# min      70.00000  10.0    1.00000   1.877887e+01  28811.000000  133.351814
# 25%      72.25000  10.0    3.25000   1.556557e+02  28811.000000  137.165606
# 50%      74.50000  10.0    5.50000   4.524112e+08  28811.000000  137.371757
# 75%      76.75000  10.0    7.75000  9.336229e+101  28811.000000  139.213716
# max      79.00000  10.0   10.00000            inf  35670.000000  142.559028

# %%
kohonenD20.describe()
# Out:
#        Unnamed: 0   dim  index_map      distance           ram        time
# count    10.00000  10.0   10.00000  9.000000e+00     10.000000   10.000000
# mean    164.50000  20.0    5.50000  5.912752e+50  29858.100000  274.217237
# std       3.02765   0.0    3.02765  1.773826e+51   2299.292087    2.517589
# min     160.00000  20.0    1.00000  4.767123e+01  29131.000000  269.310310
# 25%     162.25000  20.0    3.25000  5.159998e+01  29131.000000  274.088619
# 50%     164.50000  20.0    5.50000  5.276507e+01  29131.000000  274.244905
# 75%     166.75000  20.0    7.75000  9.123944e+02  29131.000000  274.589850
# max     169.00000  20.0   10.00000  5.321477e+51  36402.000000  279.681465

# %%
kohonenD50.describe()
# Out:
#        Unnamed: 0   dim  index_map    distance           ram        time
# count    10.00000  10.0   10.00000   10.000000     10.000000   10.000000
# mean    254.50000  50.0    5.50000         inf  30530.700000  629.653420
# std       3.02765   0.0    3.02765         NaN   1390.453487   19.077678
# min     250.00000  50.0    1.00000  155.285630  30091.000000  613.926842
# 25%     252.25000  50.0    3.25000  167.483146  30091.000000  618.358614
# 50%     254.50000  50.0    5.50000  179.508321  30091.000000  624.131455
# 75%     256.75000  50.0    7.75000  218.638496  30091.000000  632.163423
# max     259.00000  50.0   10.00000         inf  34488.000000  677.066418

# %%
F10k = pd.DataFrame({
    'algorithm': ['bfs', 'kohonen', 'prog_din'],
    'time': [bfsF10.time.mean(), kohonenF10.time.mean(), prog_dinF10.time.mean()],
    'distance': [bfsF10.distance.mean(), kohonenF10.distance.mean(), prog_dinF10.distance.mean()],
    'ram': [bfsF10.ram.mean(), kohonenF10.ram.mean(), prog_dinF10.ram.mean()]
})

F20k = pd.DataFrame({
    'algorithm': ['bfs', 'kohonen', 'prog_din'],
    'time': [bfsF20.time.mean(), kohonenF20.time.mean(), prog_dinF20.time.mean()],
    'distance': [bfsF20.distance.mean(), kohonenF20.distance.mean(), prog_dinF20.distance.mean()],
    'ram': [bfsF20.ram.mean(), kohonenF20.ram.mean(), prog_dinF20.ram.mean()]
})

F50k = pd.DataFrame({
    'algorithm': ['bfs', 'kohonen', 'prog_din'],
    'time': [bfsF50.time.mean(), kohonenF50.time.mean(), prog_dinF50.time.mean()],
    'distance': [bfsF50.distance.mean(), kohonenF50.distance.mean(), prog_dinF50.distance.mean()],
    'ram': [bfsF50.ram.mean(), kohonenF50.ram.mean(), prog_dinF50.ram.mean()]
})

D10k = pd.DataFrame({
    'algorithm': ['bfs', 'kohonen', 'prog_din'],
    'time': [bfsD10.time.mean(), kohonenD10.time.mean(), prog_dinD10.time.mean()],
    'distance': [bfsD10.distance.mean(), kohonenD10.distance.mean(), prog_dinD10.distance.mean()],
    'ram': [bfsD10.ram.mean(), kohonenD10.ram.mean(), prog_dinD10.ram.mean()]
})

D20k = pd.DataFrame({
    'algorithm': ['bfs', 'kohonen', 'prog_din'],
    'time': [bfsD20.time.mean(), kohonenD20.time.mean(), prog_dinD20.time.mean()],
    'distance': [bfsD20.distance.mean(), kohonenD20.distance.mean(), prog_dinD20.distance.mean()],
    'ram': [bfsD20.ram.mean(), kohonenD20.ram.mean(), prog_dinD20.ram.mean()]
})

D50k = pd.DataFrame({
    'algorithm': ['bfs', 'kohonen', 'prog_din'],
    'time': [bfsD50.time.mean(), kohonenD50.time.mean(), prog_dinD50.time.mean()],
    'distance': [bfsD50.distance.mean(), kohonenD50.distance.mean(), prog_dinD50.distance.mean()],
    'ram': [bfsD50.ram.mean(), kohonenD50.ram.mean(), prog_dinD50.ram.mean()]
})


F10 = pd.DataFrame({
    'algorithm': ['bfs', 'prog_din'],
    'time': [bfsF10.time.mean(), prog_dinF10.time.mean()],
    'distance': [bfsF10.distance.mean(),  prog_dinF10.distance.mean()],
    'ram': [bfsF10.ram.mean(), prog_dinF10.ram.mean()]
})

F20 = pd.DataFrame({
    'algorithm': ['bfs','prog_din'],
    'time': [bfsF20.time.mean(),  prog_dinF20.time.mean()],
    'distance': [bfsF20.distance.mean(),  prog_dinF20.distance.mean()],
    'ram': [bfsF20.ram.mean(),  prog_dinF20.ram.mean()]
})

F50 = pd.DataFrame({
    'algorithm': ['bfs',  'prog_din'],
    'time': [bfsF50.time.mean(),  prog_dinF50.time.mean()],
    'distance': [bfsF50.distance.mean(),  prog_dinF50.distance.mean()],
    'ram': [bfsF50.ram.mean(),  prog_dinF50.ram.mean()]
})

D10 = pd.DataFrame({
    'algorithm': ['bfs',  'prog_din'],
    'time': [bfsD10.time.mean(),  prog_dinD10.time.mean()],
    'distance': [bfsD10.distance.mean(),  prog_dinD10.distance.mean()],
    'ram': [bfsD10.ram.mean(),  prog_dinD10.ram.mean()]
})

D20 = pd.DataFrame({
    'algorithm': ['bfs', 'prog_din'],
    'time': [bfsD20.time.mean(),  prog_dinD20.time.mean()],
    'distance': [bfsD20.distance.mean(),  prog_dinD20.distance.mean()],
    'ram': [bfsD20.ram.mean(),  prog_dinD20.ram.mean()]
})

D50 = pd.DataFrame({
    'algorithm': ['bfs',  'prog_din'],
    'time': [bfsD50.time.mean(),  prog_dinD50.time.mean()],
    'distance': [bfsD50.distance.mean(),  prog_dinD50.distance.mean()],
    'ram': [bfsD50.ram.mean(),  prog_dinD50.ram.mean()]
})

# %%
srn.barplot(y=F10.time, x=F10.algorithm)
# Out:
# <Axes: xlabel='algorithm', ylabel='time'>

# %%
srn.barplot(y=F20.time, x=F10.algorithm)
# Out:
# <Axes: xlabel='algorithm', ylabel='time'>

# %%
srn.barplot(y=F50.time, x=F10.algorithm)
# Out:
# <Axes: xlabel='algorithm', ylabel='time'>

# %%
srn.barplot(y=D10.time, x=F10.algorithm)
srn.barplot(y=D20.time, x=F10.algorithm)
# Out:
# <Axes: xlabel='algorithm', ylabel='time'>

# %%
fig, axs = plt.subplots(ncols=3, figsize=(15, 5))
srn.barplot(x=F10.algorithm, y=D10.time,  ax=axs[0]).set(title='D 10X10', xlabel='')
srn.barplot(x=F10.algorithm, y=D20.time,  ax=axs[1]).set(title='D 20X20', ylabel='')
srn.barplot(x=F10.algorithm, y=D50.time,  ax=axs[2]).set(title='D 50X50', xlabel='', ylabel='')
# Out:
# [Text(0.5, 1.0, 'D 50X50'), Text(0.5, 0, ''), Text(0, 0.5, '')]

# %%
fig, axs = plt.subplots(ncols=3, figsize=(15, 5))
srn.barplot(x=F10.algorithm, y=D10.distance,  ax=axs[0]).set(title='D 10X10', xlabel='')
srn.barplot(x=F10.algorithm, y=D20.distance,  ax=axs[1]).set(title='D 20X20', ylabel='')
srn.barplot(x=F10.algorithm, y=D50.distance,  ax=axs[2]).set(title='D 50X50', xlabel='', ylabel='')
# Out:
# [Text(0.5, 1.0, 'D 50X50'), Text(0.5, 0, ''), Text(0, 0.5, '')]

# %%
fig, axs = plt.subplots(ncols=3, figsize=(15, 5))
srn.barplot(x=F10.algorithm, y=D10.ram,  ax=axs[0]).set(title='D 10X10', xlabel='')
srn.barplot(x=F10.algorithm, y=D20.ram,  ax=axs[1]).set(title='D 20X20', ylabel='')
srn.barplot(x=F10.algorithm, y=D50.ram,  ax=axs[2]).set(title='D 50X50', xlabel='', ylabel='')
# Out:
# [Text(0.5, 1.0, 'D 50X50'), Text(0.5, 0, ''), Text(0, 0.5, '')]

# %%
F10k
# Out:
#   algorithm        time   distance      ram
# 0       bfs    0.001658  18.000000  26779.0
# 1   kohonen  127.048879  20.028756  28811.0
# 2  prog_din    0.014893  18.000000  26779.0

# %%
F50k
# Out:
#   algorithm        time    distance       ram
# 0       bfs    0.045964   98.000000  346654.4
# 1   kohonen  673.846027  176.109686   30091.0
# 2  prog_din    0.505272   98.000000   26779.0

# %%
D10k
# Out:
#   algorithm        time  distance      ram
# 0       bfs    0.001301      18.0  26779.0
# 1   kohonen  138.052273       inf  29496.9
# 2  prog_din    0.011816      18.0  26779.0

# %%
D50k
# Out:
#   algorithm        time  distance       ram
# 0       bfs    0.039811      98.0  322402.4
# 1   kohonen  629.653420       inf   30530.7
# 2  prog_din    0.448611      98.0   26779.0
